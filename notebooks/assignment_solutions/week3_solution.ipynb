# %% [markdown]
# ### Programming for Biomedical Informatics
# #### Week 3 Assignment - Gene ID Conversion
#
# In this weekly mini assignment you will practice converting between different accession types using NCBI eUtils and BioMart
#
# - make sure that you've installed Biopython, signed up for a free NCBI account so that you can get an API key
# - if you deciede that you would like to try with BioMart too remember that you can (should!) practice using the BioMart web interface first so that you understand the correct parameters to use
#
# We've included the basic code below based on the weekly snippets from the GitHub ```./notebooks/week3``` feel free to explore and try different things.

# %%
# using NCBI-NLM eUtils to get gene IDs from gene symbols
from Bio import Entrez

# load your API key from the file
with open('../api_keys/ncbi.txt', 'r') as file:
    api_key = file.read().strip()

# load your email from the file
with open('../api_keys/ncbi_email.txt', 'r') as file:
    email = file.read().strip()

Entrez.api_key = api_key
Entrez.email = email

## NB I modified this to do a faster search using the OR string
def get_gene_ids(gene_symbols, organism="Homo sapiens"):
    """
    Convert a list of gene symbols into NCBI Gene IDs.

    Parameters:
    gene_symbols (list): List of gene symbols to search for.
    organism (str): Organism name to restrict search (default is "Homo sapiens").

    Returns:
    dict: A dictionary mapping gene symbols to NCBI Gene IDs.
    """
    gene_ids = {}
    search_string = " OR ".join([f"{symbol}[Gene]" for symbol in gene_symbols])
    search_string += f" AND {organism}[Organism]"

    handle = Entrez.esearch(db="gene", term=search_string, retmax=len(gene_symbols))
    record = Entrez.read(handle)
    handle.close()

    for symbol, gene_id in zip(gene_symbols, record["IdList"]):
        gene_ids[symbol] = gene_id if gene_id else None

    return gene_ids

# %%
'''In last week's assignment you looked up the genes associated with Alzheimer's disease using the Reactome API.
Now, let's parse the list you recovered to extract the gene symbol, this is the first element after 
the hsa:12344 number from last week's mapping:

e.g.

hsa:10000	AKT3, MPPH, MPPH2, PKB-GAMMA, PKBG, PRKBG, RAC-PK-gamma, RAC-gamma, STK-2; AKT serine/threonine kinase 3
hsa:100137049	PLA2G4B, HsT16992, cPLA2-beta; phospholipase A2 group IVB
hsa:10125	RASGRP1, CALDAG-GEFI, CALDAG-GEFII, IMD64, RASGRP; RAS guanyl releasing protein 1
....

This can be done using the python first splitting on ```tab``` and then using split on ```,``` to get the gene symbol.
Save the gene symbols to a file called alzheimers_genes.txt.
'''

# pseudocode1
# Use code from last week (solution for that posted on GitHub) to get the gene symbols data as above
'''###YOUR CODE HERE###'''
# Importing the required libraries
import requests

# Function to download KEGG pathway data
def download_kegg_pathway_genes(pathway_id):
    # URL for the pathway data
    data_url = f"http://rest.kegg.jp/link/hsa/{pathway_id}"
    
    # Make the HTTP request for the pathway data
    response = requests.get(data_url)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Write the data content to a file
        with open(f"{pathway_id}.txt", 'w') as file:
            file.write(response.text)
        print(f"Pathway data saved as {pathway_id}.txt")
    else:
        print("Failed to retrieve pathway data. Status code:", response.status_code)

# Example pathway ID for Alzheimer's disease
pathway_id = "hsa05010"

# Call the functions to download the pathway image and data
download_kegg_pathway_genes(pathway_id)
# Out:
# Pathway data saved as hsa05010.txt

# %%
# pseudocode2
# Parse the data to extract the gene symbol
'''###YOUR CODE HERE###'''
import pandas as pd
df = pd.read_csv('hsa05010.txt', sep='\t', header=None)

# the second column contians the gene ids, use the first 5 (for speed) to fetch the gene details
gene_ids = df.iloc[:, 1]

# Function to fetch gene details
def fetch_gene_details(gene_ids):
    gene_details = dict()
    for gene_id in gene_ids:
        # URL for the pathway data
        data_url = f"http://rest.kegg.jp/list/{gene_id}"
        
        # Make the HTTP request for the pathway data
        response = requests.get(data_url)
        
        # Check if the request was successful
        if response.status_code == 200:
            #strip the newline character from the response text
            response = response.text.strip()
            #ad the gene details to the dictionary
            gene_details[gene_id] = response
            print(response)
        else:
            print("Failed to retrieve gene data. Status code:", response.status_code)
    return gene_details

# Call the function to fetch gene details
# this will take a while to run (c.15 minutes)
gene_details = fetch_gene_details(gene_ids)
# Out:
# hsa:10000	AKT3, MPPH, MPPH2, PKB-GAMMA, PKBG, PRKBG, RAC-PK-gamma, RAC-gamma, STK-2; AKT serine/threonine kinase 3
# hsa:10023	FRAT1; FRAT regulator of WNT signaling pathway 1
# hsa:100506742	CASP12, CASP-12, CASP12P1; caspase 12 (gene/pseudogene)
# hsa:100532726	NDUFC2-KCTD14; NDUFC2-KCTD14 readthrough
# hsa:10105	PPIF, CYP3, CyP-M, Cyp-D, CypD; peptidylprolyl isomerase F
# hsa:102	ADAM10, AD10, AD18, CD156c, CDw156, HsT18717, MADM, RAK, kuz; ADAM metallopeptidase domain 10
# hsa:1020	CDK5, LIS7, PSSALRE; cyclin dependent kinase 5
# hsa:10213	PSMD14, PAD1, POH1, RPN11; proteasome 26S subunit, non-ATPase 14
# hsa:102800317	TPTEP2-CSNK1E, LOC400927-CSNK1E; TPTEP2-CSNK1E readthrough
# hsa:10297	APC2, APCL, MRT74; APC regulator of WNT signaling pathway 2
# hsa:10313	RTN3, ASYIP, HAP, NSPL2, NSPLII, RTN3-A1; reticulon 3
# hsa:10376	TUBA1B, K-ALPHA-1; tubulin alpha 1b
# hsa:10381	TUBB3, CDCBM, CDCBM1, CFEOM3, CFEOM3A, FEOM3, TUBB4, beta-4; tubulin beta 3 class III
# hsa:10382	TUBB4A, DYT4, TUBB4, beta-5; tubulin beta 4A class IVa
# hsa:10383	TUBB4B, Beta2, LCAEOD, TUBB2, TUBB2C; tubulin beta 4B class IVb
# hsa:10476	ATP5PD, APT5H, ATP5H, ATPQ; ATP synthase peripheral stalk subunit d
# hsa:107984365	cytochrome c oxidase subunit NDUFA4-like
# hsa:10975	UQCR11, 0710008D09Rik, QCR10, UQCR; ubiquinol-cytochrome c reductase, complex III subunit XI
# hsa:110117499	P3R3URF-PIK3R3, LOC110117498-PIK3R3; P3R3URF-PIK3R3 readthrough
# hsa:11047	ADRM1, ARM-1, ARM1, GP110, PSMD16; ADRM1 26S proteasome ubiquitin receptor
# hsa:11211	FZD10, CD350, FZ-10, Fz10, FzE7, hFz10; frizzled class receptor 10
# hsa:112714	TUBA3E; tubulin alpha 3e
# hsa:1128	CHRM1, HM1, M1, M1R; cholinergic receptor muscarinic 1
# hsa:1131	CHRM3, EGBRS, HM3, PBS, m3AChR; cholinergic receptor muscarinic 3
# hsa:1133	CHRM5, HM5; cholinergic receptor muscarinic 5
# hsa:113457	TUBA3D, H2-ALPHA, KTCN9, TUBA2; tubulin alpha 3d
# hsa:1139	CHRNA7, CHRNA7-2, NACHRA7; cholinergic receptor nicotinic alpha 7 subunit
# hsa:1147	CHUK, BPS2, IKBKA, IKK-1, IKK-alpha, IKK1, IKKA, NFKBIKA, TCF16; component of inhibitor of nuclear factor kappa B kinase complex
# hsa:122011	CSNK1A1L, CK1; casein kinase 1 alpha 1 like
# hsa:124908013	tubulin beta 8B
# hsa:124908015	tubulin beta 8B
# hsa:124908041	tubulin beta 8B
# hsa:125965	COX6B2, COXVIB2, CT59; cytochrome c oxidase subunit 6B2
# hsa:126328	NDUFA11, B14.7, CI-B14.7, MC1DN14; NADH:ubiquinone oxidoreductase subunit A11
# hsa:1327	COX4I1, COX_IV-1, COX4, COX4-1, COXIV, COXIV-1, MC4DN16; cytochrome c oxidase subunit 4I1
# hsa:1329	COX5B, COXVB; cytochrome c oxidase subunit 5B
# hsa:1337	COX6A1, CMTRID, COX6A, COX6AL; cytochrome c oxidase subunit 6A1
# hsa:1339	COX6A2, COX6AH, COXVIAH, COXVIa-M, MC4DN18; cytochrome c oxidase subunit 6A2
# hsa:1340	COX6B1, COX6B, COXG, COXVIb1, MC4DN7; cytochrome c oxidase subunit 6B1
# hsa:1345	COX6C; cytochrome c oxidase subunit 6C
# hsa:1346	COX7A1, COX7A, COX7AH, COX7AM; cytochrome c oxidase subunit 7A1
# hsa:1347	COX7A2, COX7AL, COX7AL1, COXVIIAL, COXVIIa-L, VIIAL; cytochrome c oxidase subunit 7A2
# hsa:1349	COX7B, APLCC, LSDMCA2; cytochrome c oxidase subunit 7B
# hsa:1350	COX7C; cytochrome c oxidase subunit 7C
# hsa:1351	COX8A, COX, COX8, COX8-2, COX8L, MC4DN15, VIII, VIII-L; cytochrome c oxidase subunit 8A
# hsa:143471	PSMA8, PSMA7L; proteasome 20S subunit alpha 8
# hsa:1435	CSF1, CSF-1, MCSF, PG-M-CSF; colony stimulating factor 1
# hsa:1452	CSNK1A1, CK1, CK1a, CKIa, HEL-S-77p, HLCDGP1, PRO2975; casein kinase 1 alpha 1
# hsa:1454	CSNK1E, CKIe, CKIepsilon, HCKIE; casein kinase 1 epsilon
# hsa:1457	CSNK2A1, CK2A1, CKII, Cka1, Cka2, OCNDS; casein kinase 2 alpha 1
# hsa:1459	CSNK2A2, CK2A2, CK2alpha', CSNK2A1; casein kinase 2 alpha 2
# hsa:1460	CSNK2B, CK2B, CK2N, CSK2B, Ckb1, Ckb2, G5A, POBINDS; casein kinase 2 beta
# hsa:147700	KLC3, KLC2, KLC2L, KLCt, KNS2B; kinesin light chain 3
# hsa:1499	CTNNB1, CTNNB, EVR7, MRD19, NEDSDV, armadillo; catenin beta 1
# hsa:1536	CYBB, AMCBX2, CGD, CGDX, GP91-1, GP91-PHOX, GP91PHOX, IMD34, NOX2, p91-PHOX; cytochrome b-245 beta chain
# hsa:1537	CYC1, MC3DN6, UQCR4; cytochrome c1
# hsa:163688	CALML6, CAGLP; calmodulin like 6
# hsa:1649	DDIT3, AltDDIT3, C/EBPzeta, CEBPZ, CHOP, CHOP-10, CHOP10, GADD153; DNA damage inducible transcript 3
# hsa:170712	COX7B2; cytochrome c oxidase subunit 7B2
# hsa:177	AGER, RAGE, SCARJ1, sRAGE; advanced glycosylation end-product specific receptor
# hsa:1855	DVL1, DRS2, DVL, DVL1L1, DVL1P1; dishevelled segment polarity protein 1
# hsa:1856	DVL2; dishevelled segment polarity protein 2
# hsa:1857	DVL3, DRS3; dishevelled segment polarity protein 3
# hsa:1965	EIF2S1, EIF-2, EIF-2A, EIF-2alpha, EIF2, EIF2A; eukaryotic translation initiation factor 2 subunit alpha
# hsa:201266	SLC39A11, C17orf26, ZIP-11, ZIP11; solute carrier family 39 member 11
# hsa:203068	TUBB, CDCBM6, CSCSC1, M40, OK/SW-cl.56, TUBB1, TUBB5; tubulin beta class I
# hsa:207	AKT1, AKT, PKB, PKB-ALPHA, PRKBA, RAC, RAC-ALPHA; AKT serine/threonine kinase 1
# hsa:208	AKT2, HIHGHH, PKBB, PKBBETA, PRKBB, RAC-BETA; AKT serine/threonine kinase 2
# hsa:2081	ERN1, IRE1, IRE1P, IRE1a, hIRE1p; endoplasmic reticulum to nucleus signaling 1
# hsa:221074	SLC39A12, LZT-Hs8, ZIP-12, ZIP12, bA570F3.1; solute carrier family 39 member 12
# hsa:22863	ATG14, ATG14L, BARKOR, KIAA0831; autophagy related 14
# hsa:22926	ATF6, ACHM7, ATF6A, ATP6alpha; activating transcription factor 6
# hsa:22943	DKK1, DKK-1, SK; dickkopf WNT signaling pathway inhibitor 1
# hsa:23130	ATG2A, BLTP4A; autophagy related 2A
# hsa:23236	PLCB1, DEE12, EIEE12, PI-PLC, PLC-154, PLC-I, PLC-beta-1, PLC154, PLCB1A, PLCB1B; phospholipase C beta 1
# hsa:23385	NCSTN, ATAG1874; nicastrin
# hsa:23401	FRAT2, FRAT-2; FRAT regulator of WNT signaling pathway 2
# hsa:23516	SLC39A14, HCIN, HMNDYT2, LZT-Hs4, NET34, ZIP14, cig19; solute carrier family 39 member 14
# hsa:23621	BACE1, ASP2, BACE, HSPC104; beta-secretase 1
# hsa:2475	MTOR, FRAP, FRAP1, FRAP2, RAFT1, RAPT1, SKS; mechanistic target of rapamycin kinase
# hsa:2535	FZD2, Fz2, OMOD2, fz-2, fzE2, hFz2; frizzled class receptor 2
# hsa:25800	SLC39A6, LIV-1, LIV1, ZIP6; solute carrier family 39 member 6
# hsa:25825	BACE2, AEPLC, ALP56, ASP1, ASP21, BAE2, CDA13, CEAP1, DRAP; beta-secretase 2
# hsa:2597	GAPDH, G3PD, GAPD, HEL-S-162eP; glyceraldehyde-3-phosphate dehydrogenase
# hsa:260334	TUBB8B, TUBB8P12; tubulin beta 8B
# hsa:26100	WIPI2, ATG18B, Atg21, CGI-50, IDDSSA, WIPI-2; WD repeat domain, phosphoinositide interacting 2
# hsa:27035	NOX1, GP91-2, MOX1, NOH-1, NOH-1L, NOH1; NADPH oxidase 1
# hsa:27089	UQCRQ, MC3DN4, QCR8, QP-C, QPC, UQCR7; ubiquinol-cytochrome c reductase complex III subunit VII
# hsa:27121	DKK4, DKK-4; dickkopf WNT signaling pathway inhibitor 4
# hsa:27123	DKK2, DKK-2; dickkopf WNT signaling pathway inhibitor 2
# hsa:27173	SLC39A1, ZIP1, ZIRTL; solute carrier family 39 member 1
# hsa:2776	GNAQ, CMAL, CMC1, G-ALPHA-q, GAQ, SWS; G protein subunit alpha q
# hsa:283106	CSNK2A3, CSNK2A1P; casein kinase 2 alpha 3
# hsa:283375	SLC39A5, LZT-Hs7, MYP24, ZIP5; solute carrier family 39 member 5
# hsa:2902	GRIN1, DEE101, GluN1, MRD8, NDHMSD, NDHMSR, NMD-R1, NMDA1, NMDAR1, NR1; glutamate ionotropic receptor NMDA type subunit 1
# hsa:2903	GRIN2A, EPND, FESD, GluN2A, LKS, NMDAR2A, NR2A; glutamate ionotropic receptor NMDA type subunit 2A
# hsa:2904	GRIN2B, DEE27, EIEE27, GluN2B, MRD6, NMDAR2B, NR2B, NR3, hNR3; glutamate ionotropic receptor NMDA type subunit 2B
# hsa:2905	GRIN2C, GluN2C, NMDAR2C, NR2C; glutamate ionotropic receptor NMDA type subunit 2C
# hsa:2906	GRIN2D, DEE46, EB11, EIEE46, GluN2D, NMDAR2D, NR2D; glutamate ionotropic receptor NMDA type subunit 2D
# hsa:291	SLC25A4, AAC1, ANT, ANT_1, ANT1, MTDPS12, MTDPS12A, PEO2, PEO3, PEOA2, T1; solute carrier family 25 member 4
# hsa:2915	GRM5, GPRC1E, MGLUR5, PPP1R86, mGlu5; glutamate metabotropic receptor 5
# hsa:292	SLC25A5, 2F1, AAC2, ANT2, T2, T3; solute carrier family 25 member 5
# hsa:293	SLC25A6, AAC3, ANT, ANT_2, ANT_3, ANT3, ANT3Y; solute carrier family 25 member 6
# hsa:2932	GSK3B; glycogen synthase kinase 3 beta
# hsa:29796	UQCR10, HSPC051, HSPC119, HSPC151, QCR9, UCCR7.2, UCRC; ubiquinol-cytochrome c reductase, complex III subunit X
# hsa:29982	NRBF2, COPR, COPR1, COPR2, NRBF-2; nuclear receptor binding factor 2
# hsa:29985	SLC39A3, ZIP-3, ZIP3; solute carrier family 39 member 3
# hsa:29986	SLC39A2, 6A1, ETI-1, ZIP-2, ZIP2; solute carrier family 39 member 2
# hsa:3028	HSD17B10, 17b-HSD10, ABAD, CAMR, DUPXp11.22, ERAB, HADH2, HCD2, HSD10MD, MHBD, MRPP2, MRX17, MRX31, MRXS10, SCHAD, SDR5C1; hydroxysteroid 17-beta dehydrogenase 10
# hsa:30849	PIK3R4, VPS15, p150; phosphoinositide-3-kinase regulatory subunit 4
# hsa:317	APAF1, APAF-1, CED4; apoptotic peptidase activating factor 1
# hsa:322	APBB1, FE65, MGC:9072, RIR; amyloid beta precursor protein binding family B member 1
# hsa:324	APC, BTPS2, DESMD, DP2, DP2.5, DP3, GS, PPP1R46; APC regulator of WNT signaling pathway
# hsa:3265	HRAS, C-BAS/HAS, C-H-RAS, C-HA-RAS1, CTLO, H-RASIDX, HAMSV, HRAS1, RASH1, p21ras; HRas proto-oncogene, GTPase
# hsa:3416	IDE, INSULYSIN; insulin degrading enzyme
# hsa:341947	COX8C, COX8-3; cytochrome c oxidase subunit 8C
# hsa:347688	TUBB8, OOMD, OOMD2, OZEMA2, bA631M21.2; tubulin beta 8 class VIII
# hsa:347733	TUBB2B, CDCBM7, PMGYSA, bA506K6.1; tubulin beta 2B class IIb
# hsa:348	APOE, AD2, APO-E, ApoE4, LDLCQ5, LPG; apolipoprotein E
# hsa:351	APP, AAA, ABETA, ABPP, AD1, APPI, CTFgamma, CVAP, PN-II, PN2, alpha-sAPP, preA4; amyloid beta precursor protein
# hsa:355	FAS, ALPS1A, APO-1, APT1, CD95, FAS1, FASTM, TNFRSF6; Fas cell surface death receptor
# hsa:3551	IKBKB, IKK-2, IKK-beta, IKK2, IKKB, IMD15, IMD15A, IMD15B, NFKBIKB; inhibitor of nuclear factor kappa B kinase subunit beta
# hsa:3552	IL1A, IL-1_alpha, IL-1A, IL1, IL1-ALPHA, IL1F1; interleukin 1 alpha
# hsa:3553	IL1B, IL-1, IL1-BETA, IL1F2, IL1beta; interleukin 1 beta
# hsa:3569	IL6, BSF-2, BSF2, CDF, HGF, HSF, IFN-beta-2, IFNB2, IL-6; interleukin 6
# hsa:3630	INS, IDDM, IDDM1, IDDM2, ILPR, IRDN, MODY10, PNDM4; insulin
# hsa:3643	INSR, CD220, HHF5; insulin receptor
# hsa:3667	IRS1, HIRS-1; insulin receptor substrate 1
# hsa:369	ARAF, A-RAF, ARAF1, PKS2, RAFA1; A-Raf proto-oncogene, serine/threonine kinase
# hsa:3708	ITPR1, ACV, CLA4, INSP3R1, IP3R, IP3R1, PPP1R94, SCA15, SCA16, SCA29; inositol 1,4,5-trisphosphate receptor type 1
# hsa:3709	ITPR2, ANHD, CFAP48, INSP3R2, IP3R2; inositol 1,4,5-trisphosphate receptor type 2
# hsa:3710	ITPR3, CMT1J, IP3R, IP3R-3, IP3R3; inositol 1,4,5-trisphosphate receptor type 3
# hsa:374291	NDUFS7, CI-20, CI-20KD, MC1DN3, MY017, PSST; NADH:ubiquinone oxidoreductase core subunit S7
# hsa:3798	KIF5A, ALS25, D12S1889, MY050, NEIMY, NKHC, SPG10; kinesin family member 5A
# hsa:3799	KIF5B, HEL-S-61, KINH, KNS, KNS1, UKHC; kinesin family member 5B
# hsa:3800	KIF5C, CDCBM2, KINN, NKHC, NKHC-2, NKHC2; kinesin family member 5C
# hsa:3831	KLC1, KLC, KNS2, KNS2A; kinesin light chain 1
# hsa:3845	KRAS, 'C-K-RAS, C-K-RAS, CFC2, K-RAS2A, K-RAS2B, K-RAS4A, K-RAS4B, K-Ras, K-Ras_2, KI-RAS, KRAS1, KRAS2, NS, NS3, OES, RALD, RASK2, c-Ki-ras, c-Ki-ras2; KRAS proto-oncogene, GTPase
# hsa:4023	LPL, HDLCQ11, LIPD; lipoprotein lipase
# hsa:4035	LRP1, A2MR, APOER, APR, CD91, DDH3, IGFBP-3R, IGFBP3R, IGFBP3R1, KPA, LRP, LRP1A, TGFBR5; LDL receptor related protein 1
# hsa:4040	LRP6, ADCAD2, STHAG7; LDL receptor related protein 6
# hsa:4041	LRP5, BMND1, EVR1, EVR4, HBM, LR3, LRP-5, LRP-7, LRP7, OPPG, OPS, OPTA1, PCLD4, VBCH2; LDL receptor related protein 5
# hsa:4137	MAPT, DDPAC, FTD1, FTDP-17, MAPTL, MSTD, MTBT1, MTBT2, PPND, PPP1R103, TAU, Tau-PHF6, tau-40; microtubule associated protein tau
# hsa:4217	MAP3K5, ASK1, MAPKKK5, MEKK5; mitogen-activated protein kinase kinase kinase 5
# hsa:4311	MME, CALLA, CD10, CMT2T, NEP, SCA43, SFE; membrane metalloendopeptidase
# hsa:440567	UQCRHL, hCG25371; ubiquinol-cytochrome c reductase hinge protein like
# hsa:441925	BECN2, BECN1L1, BECN1P1; beclin 2
# hsa:4508	ATP6, ATPase6, MTATP6, MT-ATP6, RP; ATP synthase F0 subunit 6
# hsa:4509	ATP8, ATPase8, MTATP8, MT-ATP8; ATP synthase F0 subunit 8
# hsa:4512	COX1, COI, MTCO1, MT-CO1; cytochrome c oxidase subunit I
# hsa:4513	COX2, COII, MTCO2, MT-CO2; cytochrome c oxidase subunit II
# hsa:4514	COX3, COIII, MTCO3, MT-CO3; cytochrome c oxidase subunit III
# hsa:4519	CYTB, MTCYB, MT-CYB; cytochrome b
# hsa:4535	ND1, MTND1, MT-ND1; NADH dehydrogenase subunit 1
# hsa:4536	ND2, MTND2, MT-ND2; NADH dehydrogenase subunit 2
# hsa:4537	ND3, MTND3, MT-ND3; NADH dehydrogenase subunit 3
# hsa:4538	ND4, MTND4, MT-ND4, LHON; NADH dehydrogenase subunit 4
# hsa:4539	ND4L, MTND4L, MT-ND4L; NADH dehydrogenase subunit 4L
# hsa:4540	ND5, MTND5, MT-ND5; NADH dehydrogenase subunit 5
# hsa:4541	ND6, MTND6, MT-ND6; NADH dehydrogenase subunit 6
# hsa:468	ATF4, CREB-2, CREB2, TAXREB67, TXREB; activating transcription factor 4
# hsa:4694	NDUFA1, CI-MWFE, MC1DN12, MWFE, ZNF183; NADH:ubiquinone oxidoreductase subunit A1
# hsa:4695	NDUFA2, B8, CD14, CIB8, MC1DN13; NADH:ubiquinone oxidoreductase subunit A2
# hsa:4696	NDUFA3, B9, CI-B9; NADH:ubiquinone oxidoreductase subunit A3
# hsa:4697	NDUFA4, CI-9k, CI-MLRQ, COXFA4, MC4DN21, MISTR1, MLRQ, MRCAF1; NDUFA4 mitochondrial complex associated
# hsa:4698	NDUFA5, B13, CI-13KD-B, CI-13kB, NUFM, UQOR13; NADH:ubiquinone oxidoreductase subunit A5
# hsa:4700	NDUFA6, B14, CI-B14, LYRM6, MC1DN33, NADHB14; NADH:ubiquinone oxidoreductase subunit A6
# hsa:4701	NDUFA7, B14.5a, CI-B14.5a; NADH:ubiquinone oxidoreductase subunit A7
# hsa:4702	NDUFA8, CI-19KD, CI-PGIV, MC1DN37, PGIV; NADH:ubiquinone oxidoreductase subunit A8
# hsa:4704	NDUFA9, CC6, CI-39k, CI39k, COQ11, MC1DN26, NDUFS2L, SDR22E1; NADH:ubiquinone oxidoreductase subunit A9
# hsa:4705	NDUFA10, CI-42KD, CI-42k, MC1DN22; NADH:ubiquinone oxidoreductase subunit A10
# hsa:4706	NDUFAB1, ACP, ACP1, FASN2A, SDAP; NADH:ubiquinone oxidoreductase subunit AB1
# hsa:4707	NDUFB1, CI-MNLL, CI-SGDH, MNLL; NADH:ubiquinone oxidoreductase subunit B1
# hsa:4708	NDUFB2, AGGG, CI-AGGG; NADH:ubiquinone oxidoreductase subunit B2
# hsa:4709	NDUFB3, B12, CI-B12, MC1DN25; NADH:ubiquinone oxidoreductase subunit B3
# hsa:4710	NDUFB4, B15, CI-B15; NADH:ubiquinone oxidoreductase subunit B4
# hsa:4711	NDUFB5, CISGDH, SGDH; NADH:ubiquinone oxidoreductase subunit B5
# hsa:4712	NDUFB6, B17, CI; NADH:ubiquinone oxidoreductase subunit B6
# hsa:4713	NDUFB7, B18, CI-B18, MC1DN39; NADH:ubiquinone oxidoreductase subunit B7
# hsa:4714	NDUFB8, ASHI, CI-ASHI, MC1DN32; NADH:ubiquinone oxidoreductase subunit B8
# hsa:4715	NDUFB9, B22, CI-B22, LYRM3, MC1DN24, UQOR22; NADH:ubiquinone oxidoreductase subunit B9
# hsa:4716	NDUFB10, MC1DN35, PDSW; NADH:ubiquinone oxidoreductase subunit B10
# hsa:4717	NDUFC1, KFYI; NADH:ubiquinone oxidoreductase subunit C1
# hsa:4718	NDUFC2, B14.5b, CI-B14.5b, HLC-1, MC1DN36, NADHDH2; NADH:ubiquinone oxidoreductase subunit C2
# hsa:4719	NDUFS1, CI-75Kd, CI-75k, MC1DN5, PRO1304; NADH:ubiquinone oxidoreductase core subunit S1
# hsa:4720	NDUFS2, CI-49, LHONAR2, MC1DN6; NADH:ubiquinone oxidoreductase core subunit S2
# hsa:4722	NDUFS3, CI-30, MC1DN8; NADH:ubiquinone oxidoreductase core subunit S3
# hsa:4723	NDUFV1, CI-51K, CI51KD, MC1DN4, UQOR1; NADH:ubiquinone oxidoreductase core subunit V1
# hsa:4724	NDUFS4, AQDQ, CI-18, CI-18_kDa, CI-AQDQ, MC1DN1; NADH:ubiquinone oxidoreductase subunit S4
# hsa:4725	NDUFS5, CI-15k, CI15K; NADH:ubiquinone oxidoreductase subunit S5
# hsa:4726	NDUFS6, CI-13kA, CI-13kD-A, CI13KDA, MC1DN9; NADH:ubiquinone oxidoreductase subunit S6
# hsa:4728	NDUFS8, CI-23k, CI23KD, MC1DN2, TYKY; NADH:ubiquinone oxidoreductase core subunit S8
# hsa:4729	NDUFV2, CI-24k, MC1DN7; NADH:ubiquinone oxidoreductase core subunit V2
# hsa:4731	NDUFV3, CI-10k, CI-9KD; NADH:ubiquinone oxidoreductase subunit V3
# hsa:4790	NFKB1, CVID12, EBP-1, KBF1, NF-kB, NF-kB1, NF-kappa-B1, NF-kappaB, NF-kappabeta, NFKB-p105, NFKB-p50, NFkappaB; nuclear factor kappa B subunit 1
# hsa:4842	NOS1, IHPS1, N-NOS, NC-NOS, NOS, bNOS, nNOS; nitric oxide synthase 1
# hsa:4843	NOS2, HEP-NOS, INOS, NOS, NOS2A; nitric oxide synthase 2
# hsa:487	ATP2A1, ATP2A, SERCA1; ATPase sarcoplasmic/endoplasmic reticulum Ca2+ transporting 1
# hsa:488	ATP2A2, ATP2B, DAR, DD, SERCA2; ATPase sarcoplasmic/endoplasmic reticulum Ca2+ transporting 2
# hsa:489	ATP2A3, SERCA3; ATPase sarcoplasmic/endoplasmic reticulum Ca2+ transporting 3
# hsa:4891	SLC11A2, AHMIO1, DCT1, DMT1, NRAMP2; solute carrier family 11 member 2
# hsa:4893	NRAS, ALPS4, CMNS, KRAS, N-ras, NCMS, NRAS1, NS6; NRAS proto-oncogene, GTPase
# hsa:498	ATP5F1A, ATP5A, ATP5A1, ATP5AL2, ATPM, COXPD22, HEL-S-123m, MC5DN4, MC5DN4A, MC5DN4B, MOM2, OMR, ORM, hATP1; ATP synthase F1 subunit alpha
# hsa:50507	NOX4, KOX, KOX-1, RENOX; NADPH oxidase 4
# hsa:506	ATP5F1B, ATP5B, ATPMB, ATPSB, HEL-S-271, HUMOP2; ATP synthase F1 subunit beta
# hsa:509	ATP5F1C, ATP5C, ATP5C1, ATP5CL1; ATP synthase F1 subunit gamma
# hsa:51079	NDUFA13, B16.6, CDA016, CGI-39, GRIM-19, GRIM19, MC1DN28; NADH:ubiquinone oxidoreductase subunit A13
# hsa:51107	APH1A, 6530402N02Rik, APH-1, APH-1A, CGI-78; aph-1 homolog A, gamma-secretase subunit
# hsa:513	ATP5F1D, ATP5D, MC5DN5; ATP synthase F1 subunit delta
# hsa:51384	WNT16; Wnt family member 16
# hsa:514	ATP5F1E, ATP5E, ATPE, MC5DN3; ATP synthase F1 subunit epsilon
# hsa:515	ATP5PB, ATP5F1, PIG47; ATP synthase peripheral stalk-membrane subunit b
# hsa:516	ATP5MC1, ATP5A, ATP5G, ATP5G1; ATP synthase membrane subunit c locus 1
# hsa:517	ATP5MC2, ATP5A, ATP5G2; ATP synthase membrane subunit c locus 2
# hsa:518	ATP5MC3, ATP5G3, DYTSPG, P3; ATP synthase membrane subunit c locus 3
# hsa:51806	CALML5, CLSP; calmodulin like 5
# hsa:51807	TUBA8, CDCBM8, MACTHC2, TUBAL2; tubulin alpha 8
# hsa:522	ATP5PF, ATP5, ATP5A, ATP5J, ATPM, CF6, F6; ATP synthase peripheral stalk subunit F6
# hsa:5289	PIK3C3, VPS34, hVps34; phosphatidylinositol 3-kinase catalytic subunit type 3
# hsa:5290	PIK3CA, CCM4, CLAPO, CLOVE, CWS5, HMH, MCAP, MCM, MCMTC, PI3K, PI3K-alpha, p110-alpha; phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha
# hsa:5291	PIK3CB, P110BETA, PI3K, PI3KBETA, PIK3C1; phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit beta
# hsa:5293	PIK3CD, APDS, IMD14, IMD14A, IMD14B, P110DELTA, PI3K, ROCHIS, p110D; phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit delta
# hsa:5295	PIK3R1, AGM7, GRB1, IMD36, p85, p85-ALPHA, p85alpha; phosphoinositide-3-kinase regulatory subunit 1
# hsa:5296	PIK3R2, MPPH, MPPH1, P85B, p85, p85-BETA, p85beta; phosphoinositide-3-kinase regulatory subunit 2
# hsa:5330	PLCB2, PLC-beta-2; phospholipase C beta 2
# hsa:5331	PLCB3, SMDCD; phospholipase C beta 3
# hsa:5332	PLCB4, ARCND2, ARCND2A, ARCND2B, PI-PLC; phospholipase C beta 4
# hsa:539	ATP5PO, ATP5O, ATPO, HMC08D05, MC5DN7, OSCP; ATP synthase peripheral stalk subunit OSCP
# hsa:54205	CYCS, CYC, HCS, THC4; cytochrome c, somatic
# hsa:54361	WNT4, SERKAL, WNT-4; Wnt family member 4
# hsa:54539	NDUFB11, CI-ESSS, ESSS, MC1DN30, NP17.3, Np15, P17.3; NADH:ubiquinone oxidoreductase subunit B11
# hsa:5481	PPID, CYP-40, CYPD; peptidylprolyl isomerase D
# hsa:55062	WIPI1, ATG18, ATG18A, WIPI49; WD repeat domain, phosphoinositide interacting 1
# hsa:55102	ATG2B, BLTP4B, C14orf103; autophagy related 2B
# hsa:5530	PPP3CA, ACCIID, CALN, CALNA, CALNA1, CCN1, CNA1, DEE91, IECEE, IECEE1, PPP2B; protein phosphatase 3 catalytic subunit alpha
# hsa:5532	PPP3CB, CALNA2, CALNB, CNA2, PP2Bbeta; protein phosphatase 3 catalytic subunit beta
# hsa:5533	PPP3CC, CALNA3, CNA3, PP2Bgamma; protein phosphatase 3 catalytic subunit gamma
# hsa:55334	SLC39A9, ZIP-9, ZIP9; solute carrier family 39 member 9
# hsa:5534	PPP3R1, CALNB1, CNB, CNB1; protein phosphatase 3 regulatory subunit B, alpha
# hsa:5535	PPP3R2, PPP3RL; protein phosphatase 3 regulatory subunit B, beta
# hsa:55626	AMBRA1, DCAF3, WDR94; autophagy and beclin 1 regulator 1
# hsa:55630	SLC39A4, AEZ, AWMS2, ZIP4; solute carrier family 39 member 4
# hsa:55851	PSENEN, ACNINV2, MDS033, MSTP064, PEN-2, PEN2; presenilin enhancer, gamma-secretase subunit
# hsa:5594	MAPK1, ERK, ERK-2, ERK2, ERT1, MAPK2, NS13, P42MAPK, PRKM1, PRKM2, p38, p40, p41, p41mapk, p42-MAPK; mitogen-activated protein kinase 1
# hsa:5595	MAPK3, ERK-1, ERK1, ERT2, HS44KDAP, HUMKER1A, P44ERK1, P44MAPK, PRKM3, p44-ERK1, p44-MAPK; mitogen-activated protein kinase 3
# hsa:55967	NDUFA12, B17.2, DAP13, MC1DN23; NADH:ubiquinone oxidoreductase subunit A12
# hsa:5599	MAPK8, JNK, JNK-46, JNK1, JNK1A2, JNK21B1/2, PRKM8, SAPK1, SAPK1c; mitogen-activated protein kinase 8
# hsa:5601	MAPK9, JNK-55, JNK2, JNK2A, JNK2ALPHA, JNK2B, JNK2BETA, PRKM9, SAPK, SAPK1a, p54a, p54aSAPK; mitogen-activated protein kinase 9
# hsa:5602	MAPK10, JNK3, JNK3A, PRKM10, SAPK1b, p493F12, p54bSAPK; mitogen-activated protein kinase 10
# hsa:5604	MAP2K1, CFC3, MAPKK1, MEK1, MEL, MKK1, PRKMK1; mitogen-activated protein kinase kinase 1
# hsa:5605	MAP2K2, CFC4, MAPKK2, MEK2, MKK2, PRKMK2; mitogen-activated protein kinase kinase 2
# hsa:5609	MAP2K7, JNKK2, MAPKK7, MEK, MEK_7, MKK7, PRKMK7, SAPKK-4, SAPKK4; mitogen-activated protein kinase kinase 7
# hsa:5610	EIF2AK2, DYT33, EIF2AK1, LEUDEN, PKR, PPP1R83, PRKR; eukaryotic translation initiation factor 2 alpha kinase 2
# hsa:5663	PSEN1, ACNINV3, AD3, CMD1U, FAD, PS-1, PS1, PSNL1, S182; presenilin 1
# hsa:5664	PSEN2, AD3L, AD4, CMD1V, PS2, STM2; presenilin 2
# hsa:5682	PSMA1, HC2, HEL-S-275, NU, PROS30; proteasome 20S subunit alpha 1
# hsa:5683	PSMA2, HC3, MU, PMSA2, PSC2; proteasome 20S subunit alpha 2
# hsa:5684	PSMA3, HC8, PSC3; proteasome 20S subunit alpha 3
# hsa:5685	PSMA4, HC9, HsT17706, PSC9; proteasome 20S subunit alpha 4
# hsa:5686	PSMA5, PSC5, ZETA; proteasome 20S subunit alpha 5
# hsa:5687	PSMA6, IOTA, PROS27, p27K; proteasome 20S subunit alpha 6
# hsa:5688	PSMA7, C6, HEL-S-276, HSPC, RC6-1, XAPC7; proteasome 20S subunit alpha 7
# hsa:5689	PSMB1, HC5, NEDMHAL, PMSB1, PSC5; proteasome 20S subunit beta 1
# hsa:5690	PSMB2, HC7-I; proteasome 20S subunit beta 2
# hsa:56901	NDUFA4L2, COXFA4L2, MISTRH, NUOMS; NDUFA4 mitochondrial complex associated like 2
# hsa:5691	PSMB3, HC10-II; proteasome 20S subunit beta 3
# hsa:5692	PSMB4, HN3, HsN3, PRAAS3, PROS-26, PROS26; proteasome 20S subunit beta 4
# hsa:5693	PSMB5, LMPX, MB1; proteasome 20S subunit beta 5
# hsa:5694	PSMB6, DELTA, LMPY; proteasome 20S subunit beta 6
# hsa:5695	PSMB7; proteasome 20S subunit beta 7
# hsa:5700	PSMC1, NEDGTH, P26S4, RPT2, S4, p56; proteasome 26S subunit, ATPase 1
# hsa:5701	PSMC2, MSS1, Nbla10058, RPT1, S7; proteasome 26S subunit, ATPase 2
# hsa:5702	PSMC3, DCIDP, RPT5, TBP1; proteasome 26S subunit, ATPase 3
# hsa:5704	PSMC4, MIP224, RPT3, S6, TBP-7, TBP7; proteasome 26S subunit, ATPase 4
# hsa:5705	PSMC5, RPT6, S8, SUG-1, SUG1, TBP10, TRIP1, p45, p45/SUG; proteasome 26S subunit, ATPase 5
# hsa:5706	PSMC6, RPT5, SUG2, p42; proteasome 26S subunit, ATPase 6
# hsa:5707	PSMD1, P112, Rpn2, S1; proteasome 26S subunit, non-ATPase 1
# hsa:5708	PSMD2, P97, RPN1, S2, TRAP2; proteasome 26S subunit ubiquitin receptor, non-ATPase 2
# hsa:5709	PSMD3, P58, RPN3, S3, TSTA2; proteasome 26S subunit, non-ATPase 3
# hsa:5710	PSMD4, AF, AF-1, ASF, MCB1, Rpn10, S5A, pUB-R5; proteasome 26S subunit ubiquitin receptor, non-ATPase 4
# hsa:5713	PSMD7, MOV34, P40, Rpn8, S12; proteasome 26S subunit, non-ATPase 7
# hsa:5714	PSMD8, HEL-S-91n, HIP6, HYPF, Nin1p, Rpn12, S14, p31; proteasome 26S subunit, non-ATPase 8
# hsa:57142	RTN4, ASY, NI220/250, NOGO, NSP, NSP-CL, Nbla00271, Nbla10545, RTN-X, RTN4-A, RTN4-B1, RTN4-B2, RTN4-C; reticulon 4
# hsa:5715	PSMD9, Rpn4, p27; proteasome 26S subunit, non-ATPase 9
# hsa:5717	PSMD11, Rpn6, S9, p44.5; proteasome 26S subunit, non-ATPase 11
# hsa:5718	PSMD12, Rpn5, STISS, p55; proteasome 26S subunit, non-ATPase 12
# hsa:57181	SLC39A10, LZT-Hs2, ZIP10; solute carrier family 39 member 10
# hsa:5719	PSMD13, HSPC027, Rpn9, S11, p40.5; proteasome 26S subunit, non-ATPase 13
# hsa:572	BAD, BBC2, BCL2L8; BCL2 associated agonist of cell death
# hsa:5743	PTGS2, COX-2, COX2, GRIPGHS, PGG/HS, PGHS-2, PHS-2, hCox-2; prostaglandin-endoperoxide synthase 2
# hsa:5894	RAF1, CMD1NN, CRAF, NS5, Raf-1, c-Raf; Raf-1 proto-oncogene, serine/threonine kinase
# hsa:5970	RELA, AIF3BL3, CMCU, NFKB3, p65; RELA proto-oncogene, NF-kB subunit
# hsa:60673	ATG101, C12orf44; autophagy related 101
# hsa:6263	RYR3, CMYO20, CMYP20, RYR-3; ryanodine receptor 3
# hsa:637	BID, FP497; BH3 interacting domain death agonist
# hsa:6389	SDHA, CMD1GG, FP, MC2DN1, NDAXOA, PGL5, PPGL5, SDH1, SDH2, SDHF; succinate dehydrogenase complex flavoprotein subunit A
# hsa:6390	SDHB, CWS2, IP, MC2DN4, PGL4, PPGL4, SDH, SDH1, SDH2, SDHIP; succinate dehydrogenase complex iron sulfur subunit B
# hsa:6391	SDHC, CYB560, CYBL, PGL3, PPGL3, QPS1, SDH3; succinate dehydrogenase complex subunit C
# hsa:6392	SDHD, CBT1, CII-4, CWS3, MC2DN3, PGL, PGL1, PPGL1, QPs3, SDH4, cybS; succinate dehydrogenase complex subunit D
# hsa:64116	SLC39A8, BIGM103, CDG2N, LZT-Hs6, PP3105, ZIP8; solute carrier family 39 member 8
# hsa:64837	KLC2; kinesin light chain 2
# hsa:6622	SNCA, NACP, PARK1, PARK4, PD1; synuclein alpha
# hsa:673	BRAF, B-RAF1, B-raf, BRAF-1, BRAF1, NS7, RAFB1; B-Raf proto-oncogene, serine/threonine kinase
# hsa:6868	ADAM17, ADAM18, CD156B, CSVP, NISBD, NISBD1, TACE; ADAM metallopeptidase domain 17
# hsa:7124	TNF, DIF, TNF-alpha, TNFA, TNFSF2, TNLG1F; tumor necrosis factor
# hsa:7132	TNFRSF1A, CD120a, FPF, TBP1, TNF-R, TNF-R-I, TNF-R55, TNFAR, TNFR1, TNFR55, TNFR60, p55, p55-R, p60; TNF receptor superfamily member 1A
# hsa:7186	TRAF2, MGC:45012, RNF117, TRAP, TRAP3; TNF receptor associated factor 2
# hsa:7277	TUBA4A, ALS22, H2-ALPHA, TUBA1; tubulin alpha 4a
# hsa:7278	TUBA3C, TUBA2, bA408E5.3; tubulin alpha 3c
# hsa:7280	TUBB2A, CDCBM5, TUBB, TUBB2; tubulin beta 2A class IIa
# hsa:7381	UQCRB, MC3DN3, QCR7, QP-C, QPC, UQBC, UQBP, UQCR6, UQPC; ubiquinol-cytochrome c reductase binding protein
# hsa:7384	UQCRC1, D3S3191, PKNPY, QCR1, UQCR1; ubiquinol-cytochrome c reductase core protein 1
# hsa:7385	UQCRC2, MC3DN5, QCR2, UQCR2; ubiquinol-cytochrome c reductase core protein 2
# hsa:7386	UQCRFS1, MC3DN10, RIP1, RIS1, RISP, UQCR5; ubiquinol-cytochrome c reductase, Rieske iron-sulfur polypeptide 1
# hsa:7388	UQCRH, MC3DN11, QCR6, UQCR8; ubiquinol-cytochrome c reductase hinge protein
# hsa:7416	VDAC1, PORIN, VDAC-1; voltage dependent anion channel 1
# hsa:7417	VDAC2, POR; voltage dependent anion channel 2
# hsa:7419	VDAC3, HD-VDAC3, VDAC-3; voltage dependent anion channel 3
# hsa:7471	WNT1, BMND16, INT1, OI15; Wnt family member 1
# hsa:7472	WNT2, INT1L1, IRP; Wnt family member 2
# hsa:7473	WNT3, INT4, TETAMS; Wnt family member 3
# hsa:7474	WNT5A, hWNT5A; Wnt family member 5A
# hsa:7475	WNT6; Wnt family member 6
# hsa:7476	WNT7A, Wnt-7a; Wnt family member 7A
# hsa:7477	WNT7B; Wnt family member 7B
# hsa:7478	WNT8A, WNT8D; Wnt family member 8A
# hsa:7479	WNT8B; Wnt family member 8B
# hsa:7480	WNT10B, SHFM6, STHAG8, WNT-12; Wnt family member 10B
# hsa:7481	WNT11, HWNT11; Wnt family member 11
# hsa:7482	WNT2B, WNT13; Wnt family member 2B
# hsa:7483	WNT9A, WNT14; Wnt family member 9A
# hsa:7484	WNT9B, WNT14B, WNT15; Wnt family member 9B
# hsa:7494	XBP1, TREB-5, TREB5, XBP-1, XBP2; X-box binding protein 1
# hsa:775	CACNA1C, CACH2, CACN2, CACNA1C-IT2, CACNL1A1, CCHL1A1, CaV1.2, LQT8, NEDHLSS, TS, TS._LQT8; calcium voltage-gated channel subunit alpha1 C
# hsa:776	CACNA1D, CACH3, CACN4, CACNL1A2, CCHL1A2, Cav1.3, PASNA, SANDD; calcium voltage-gated channel subunit alpha1 D
# hsa:778	CACNA1F, AIED, COD3, COD4, CORDX, CORDX3, CSNB2, CSNB2A, CSNBX2, Cav1.4, Cav1.4alpha1, JM8, JMC8, OA2; calcium voltage-gated channel subunit alpha1 F
# hsa:779	CACNA1S, CACNL1A3, CCHL1A3, CMYO18, CMYP18, Cav1.1, DHPRM, HOKPP, HOKPP1, MHS5, TTPP1, hypoPP; calcium voltage-gated channel subunit alpha1 S
# hsa:7846	TUBA1A, B-ALPHA-1, LIS3, TUBA3; tubulin alpha 1a
# hsa:7855	FZD5, C2orf31, HFZ5, MCOPCB11; frizzled class receptor 5
# hsa:7922	SLC39A7, AGM9, D6S115E, D6S2244E, H2-KE4, HKE4, KE4, RING5, ZIP7; solute carrier family 39 member 7
# hsa:7976	FZD3, Fz-3; frizzled class receptor 3
# hsa:7979	SEM1, C7orf76, DSS1, ECD, PSMD15, SHFD1, SHFM1, SHSF1, Shfdg1; SEM1 26S proteasome subunit
# hsa:79861	TUBAL3; tubulin alpha like 3
# hsa:801	CALM1, CALML2, CAM2, CAM3, CAMB, CAMC, CAMI, CAMIII, CPVT4, DD132, LQT14, PHKD, PHKD1, caM; calmodulin 1
# hsa:80326	WNT10A, ECTD16, OODD, SSPS, STHAG4; Wnt family member 10A
# hsa:805	CALM2, CALM, CALML2, CAM1, CAM3, CAMC, CAMII, CAMIII, LQT15, PHKD, PHKD2, caM; calmodulin 2
# hsa:808	CALM3, CALM, CAM1, CAM2, CAMB, CPVT6, CaM, CaMIII, HEL-S-72, LQT16, PHKD, PHKD3; calmodulin 3
# hsa:810	CALML3, CLP; calmodulin like 3
# hsa:81027	TUBB1, MACTHC1; tubulin beta 1 class VI
# hsa:81029	WNT5B; Wnt family member 5B
# hsa:823	CAPN1, CANP, CANP1, CANPL1, SPG76, muCANP, muCL; calpain 1
# hsa:824	CAPN2, CANP2, CANPL2, CANPml, mCANP; calpain 2
# hsa:8312	AXIN1, AXIN, CMDOH, PPP1R49; axin 1
# hsa:8313	AXIN2, AXIL, ODCRCS; axin 2
# hsa:8321	FZD1; frizzled class receptor 1
# hsa:8322	FZD4, CD344, EVR1, FEVR, FZD4S, Fz-4, Fz4, FzE4, GPCR, hFz4; frizzled class receptor 4
# hsa:8323	FZD6, FZ-6, FZ6, HFZ6, NDNC1, NDNC10; frizzled class receptor 6
# hsa:8324	FZD7, FzE3; frizzled class receptor 7
# hsa:8325	FZD8, FZ-8, hFZ8; frizzled class receptor 8
# hsa:8326	FZD9, CD349, FZD3; frizzled class receptor 9
# hsa:83447	SLC25A31, AAC4, ANT_4, ANT4, SFEC35kDa; solute carrier family 25 member 31
# hsa:83464	APH1B, APH-1B, PRO1328, PSFL, TAAV688, aph-1beta; aph-1 homolog B, gamma-secretase subunit
# hsa:836	CASP3, CPP32, CPP32B, SCA-1; caspase 3
# hsa:840	CASP7, CASP-7, CMH-1, ICE-LAP3, LICE2, MCH3; caspase 7
# hsa:8408	ULK1, ATG1, ATG1A, UNC51, Unc51.1, hATG1; unc-51 like autophagy activating kinase 1
# hsa:841	CASP8, ALPS2B, CAP4, Casp-8, FLICE, MACH, MCH5; caspase 8
# hsa:842	CASP9, APAF-3, APAF3, ICE-LAP6, MCH6, PPP1R56; caspase 9
# hsa:84617	TUBB6, FPVEPD, HsT1601, TUBB-5; tubulin beta 6 class V
# hsa:84701	COX4I2, COX4, COX4-2, COX4B, COX4L2, COXIV-2, dJ857M17.2; cytochrome c oxidase subunit 4I2
# hsa:8471	IRS4, CHNG9, IRS-4, PY160; insulin receptor substrate 4
# hsa:84790	TUBA1C, TUBA6, bcm948; tubulin alpha 1c
# hsa:8503	PIK3R3, p55, p55-GAMMA, p55PIK; phosphoinositide-3-kinase regulatory subunit 3
# hsa:8517	IKBKG, AMCBX1, EDAID1, FIP-3, FIP3, Fip3p, IKK-gamma, IKKAP1, IKKG, IMD33, IP, IP1, IP2, IPD2, NEMO, SAIDX, ZC2HC9; inhibitor of nuclear factor kappa B kinase regulatory subunit gamma
# hsa:8660	IRS2, IRS-2; insulin receptor substrate 2
# hsa:8678	BECN1, ATG6, VPS30, beclin1; beclin 1
# hsa:8772	FADD, GIG3, IMD90, MORT1; Fas associated via death domain
# hsa:8851	CDK5R1, CDK5P35, CDK5R, NCK5A, p23, p25, p35, p35nck5a; cyclin dependent kinase 5 regulatory subunit 1
# hsa:8883	NAE1, A-116A10.1, APPBP1, HPP1, NEDFIH, ula-1; NEDD8 activating enzyme E1 subunit 1
# hsa:89780	WNT3A; Wnt family member 3A
# hsa:89832	CHRFAM7A, CHRNA7, CHRNA7-DR1, D-10, NACHRA7; CHRNA7 (exons 5-10) and FAM7A (exons A-E) fusion
# hsa:89953	KLC4, KNSL8, bA387M24.3; kinesin light chain 4
# hsa:90550	MCU, C10orf42, CCDC109A, HsMCU; mitochondrial calcium uniporter
# hsa:91252	SLC39A13, EDSSPD3, LZT-Hs9, SCDEDS, ZIP13; solute carrier family 39 member 13
# hsa:9167	COX7A2L, COX7AR, COX7RP, EB1, SCAF1, SCAFI, SIG81; cytochrome c oxidase subunit 7A2 like
# hsa:91860	CALML4, NY-BR-20; calmodulin like 4
# hsa:9377	COX5A, COX, COX-VA, MC4DN20, VA; cytochrome c oxidase subunit 5A
# hsa:9451	EIF2AK3, PEK, PERK, WRS; eukaryotic translation initiation factor 2 alpha kinase 3
# hsa:9706	ULK2, ATG1B, Unc51.2; unc-51 like autophagy activating kinase 2
# hsa:9776	ATG13, KIAA0652, PARATARG8; autophagy related 13
# hsa:9821	RB1CC1, ATG17, CC1, FIP200, PPP1R131; RB1 inducible coiled-coil 1
# hsa:9861	PSMD6, Rpn7, S10, SGA-113M, p42A, p44S10; proteasome 26S subunit, non-ATPase 6

# %%
# save gene_details as a pickle file
import pickle
with open('gene_details.pkl', 'wb') as file:
    pickle.dump(gene_details, file)

# %%
# extract the first element after the hsa:12344 number
gene_symbols = []
for gene_id in gene_details:
    gene_symbol_synonym = gene_details[gene_id].split('\t')[1]
    # split on either a comma or a semi-colon
    gene_symbol = gene_symbol_synonym.split(',')[0].split(';')[0]
    gene_symbols.append(gene_symbol)

print(gene_symbols)
# Out:
# ['AKT3', 'FRAT1', 'CASP12', 'NDUFC2-KCTD14', 'PPIF', 'ADAM10', 'CDK5', 'PSMD14', 'TPTEP2-CSNK1E', 'APC2', 'RTN3', 'TUBA1B', 'TUBB3', 'TUBB4A', 'TUBB4B', 'ATP5PD', 'cytochrome c oxidase subunit NDUFA4-like', 'UQCR11', 'P3R3URF-PIK3R3', 'ADRM1', 'FZD10', 'TUBA3E', 'CHRM1', 'CHRM3', 'CHRM5', 'TUBA3D', 'CHRNA7', 'CHUK', 'CSNK1A1L', 'tubulin beta 8B', 'tubulin beta 8B', 'tubulin beta 8B', 'COX6B2', 'NDUFA11', 'COX4I1', 'COX5B', 'COX6A1', 'COX6A2', 'COX6B1', 'COX6C', 'COX7A1', 'COX7A2', 'COX7B', 'COX7C', 'COX8A', 'PSMA8', 'CSF1', 'CSNK1A1', 'CSNK1E', 'CSNK2A1', 'CSNK2A2', 'CSNK2B', 'KLC3', 'CTNNB1', 'CYBB', 'CYC1', 'CALML6', 'DDIT3', 'COX7B2', 'AGER', 'DVL1', 'DVL2', 'DVL3', 'EIF2S1', 'SLC39A11', 'TUBB', 'AKT1', 'AKT2', 'ERN1', 'SLC39A12', 'ATG14', 'ATF6', 'DKK1', 'ATG2A', 'PLCB1', 'NCSTN', 'FRAT2', 'SLC39A14', 'BACE1', 'MTOR', 'FZD2', 'SLC39A6', 'BACE2', 'GAPDH', 'TUBB8B', 'WIPI2', 'NOX1', 'UQCRQ', 'DKK4', 'DKK2', 'SLC39A1', 'GNAQ', 'CSNK2A3', 'SLC39A5', 'GRIN1', 'GRIN2A', 'GRIN2B', 'GRIN2C', 'GRIN2D', 'SLC25A4', 'GRM5', 'SLC25A5', 'SLC25A6', 'GSK3B', 'UQCR10', 'NRBF2', 'SLC39A3', 'SLC39A2', 'HSD17B10', 'PIK3R4', 'APAF1', 'APBB1', 'APC', 'HRAS', 'IDE', 'COX8C', 'TUBB8', 'TUBB2B', 'APOE', 'APP', 'FAS', 'IKBKB', 'IL1A', 'IL1B', 'IL6', 'INS', 'INSR', 'IRS1', 'ARAF', 'ITPR1', 'ITPR2', 'ITPR3', 'NDUFS7', 'KIF5A', 'KIF5B', 'KIF5C', 'KLC1', 'KRAS', 'LPL', 'LRP1', 'LRP6', 'LRP5', 'MAPT', 'MAP3K5', 'MME', 'UQCRHL', 'BECN2', 'ATP6', 'ATP8', 'COX1', 'COX2', 'COX3', 'CYTB', 'ND1', 'ND2', 'ND3', 'ND4', 'ND4L', 'ND5', 'ND6', 'ATF4', 'NDUFA1', 'NDUFA2', 'NDUFA3', 'NDUFA4', 'NDUFA5', 'NDUFA6', 'NDUFA7', 'NDUFA8', 'NDUFA9', 'NDUFA10', 'NDUFAB1', 'NDUFB1', 'NDUFB2', 'NDUFB3', 'NDUFB4', 'NDUFB5', 'NDUFB6', 'NDUFB7', 'NDUFB8', 'NDUFB9', 'NDUFB10', 'NDUFC1', 'NDUFC2', 'NDUFS1', 'NDUFS2', 'NDUFS3', 'NDUFV1', 'NDUFS4', 'NDUFS5', 'NDUFS6', 'NDUFS8', 'NDUFV2', 'NDUFV3', 'NFKB1', 'NOS1', 'NOS2', 'ATP2A1', 'ATP2A2', 'ATP2A3', 'SLC11A2', 'NRAS', 'ATP5F1A', 'NOX4', 'ATP5F1B', 'ATP5F1C', 'NDUFA13', 'APH1A', 'ATP5F1D', 'WNT16', 'ATP5F1E', 'ATP5PB', 'ATP5MC1', 'ATP5MC2', 'ATP5MC3', 'CALML5', 'TUBA8', 'ATP5PF', 'PIK3C3', 'PIK3CA', 'PIK3CB', 'PIK3CD', 'PIK3R1', 'PIK3R2', 'PLCB2', 'PLCB3', 'PLCB4', 'ATP5PO', 'CYCS', 'WNT4', 'NDUFB11', 'PPID', 'WIPI1', 'ATG2B', 'PPP3CA', 'PPP3CB', 'PPP3CC', 'SLC39A9', 'PPP3R1', 'PPP3R2', 'AMBRA1', 'SLC39A4', 'PSENEN', 'MAPK1', 'MAPK3', 'NDUFA12', 'MAPK8', 'MAPK9', 'MAPK10', 'MAP2K1', 'MAP2K2', 'MAP2K7', 'EIF2AK2', 'PSEN1', 'PSEN2', 'PSMA1', 'PSMA2', 'PSMA3', 'PSMA4', 'PSMA5', 'PSMA6', 'PSMA7', 'PSMB1', 'PSMB2', 'NDUFA4L2', 'PSMB3', 'PSMB4', 'PSMB5', 'PSMB6', 'PSMB7', 'PSMC1', 'PSMC2', 'PSMC3', 'PSMC4', 'PSMC5', 'PSMC6', 'PSMD1', 'PSMD2', 'PSMD3', 'PSMD4', 'PSMD7', 'PSMD8', 'RTN4', 'PSMD9', 'PSMD11', 'PSMD12', 'SLC39A10', 'PSMD13', 'BAD', 'PTGS2', 'RAF1', 'RELA', 'ATG101', 'RYR3', 'BID', 'SDHA', 'SDHB', 'SDHC', 'SDHD', 'SLC39A8', 'KLC2', 'SNCA', 'BRAF', 'ADAM17', 'TNF', 'TNFRSF1A', 'TRAF2', 'TUBA4A', 'TUBA3C', 'TUBB2A', 'UQCRB', 'UQCRC1', 'UQCRC2', 'UQCRFS1', 'UQCRH', 'VDAC1', 'VDAC2', 'VDAC3', 'WNT1', 'WNT2', 'WNT3', 'WNT5A', 'WNT6', 'WNT7A', 'WNT7B', 'WNT8A', 'WNT8B', 'WNT10B', 'WNT11', 'WNT2B', 'WNT9A', 'WNT9B', 'XBP1', 'CACNA1C', 'CACNA1D', 'CACNA1F', 'CACNA1S', 'TUBA1A', 'FZD5', 'SLC39A7', 'FZD3', 'SEM1', 'TUBAL3', 'CALM1', 'WNT10A', 'CALM2', 'CALM3', 'CALML3', 'TUBB1', 'WNT5B', 'CAPN1', 'CAPN2', 'AXIN1', 'AXIN2', 'FZD1', 'FZD4', 'FZD6', 'FZD7', 'FZD8', 'FZD9', 'SLC25A31', 'APH1B', 'CASP3', 'CASP7', 'ULK1', 'CASP8', 'CASP9', 'TUBB6', 'COX4I2', 'IRS4', 'TUBA1C', 'PIK3R3', 'IKBKG', 'IRS2', 'BECN1', 'FADD', 'CDK5R1', 'NAE1', 'WNT3A', 'CHRFAM7A', 'KLC4', 'MCU', 'SLC39A13', 'COX7A2L', 'CALML4', 'COX5A', 'EIF2AK3', 'ULK2', 'ATG13', 'RB1CC1', 'PSMD6']

# %%
# pseudocode3
# Save the gene symbols to a file called alzheimers_genes.txt
'''###YOUR CODE HERE###'''
with open('alzheimers_genes.txt', 'w') as file:
    for gene_symbol in gene_symbols:
        file.write(f"{gene_symbol}\n")

# %%
'''Now use the function defined above to fetch the NCBI Gene IDs for the gene symbols you extracted above. Use Pretty Table to print out a table with the first column being the gene symbol and the second column being the NCBI Gene ID.'''

# pseudocode4
# Use the function defined above to fetch the NCBI Gene IDs for the gene symbols you extracted above
'''###YOUR CODE HERE###'''
gene_ids = get_gene_ids(gene_symbols)

# save the gene_ids as a pickle file
with open('gene_ids.pkl', 'wb') as file:
    pickle.dump(gene_ids, file)

# %%
# pseudocode5
# Use Pretty Table to print out a table with the first column being the gene symbol and the second column being the NCBI Gene ID
'''###YOUR CODE HERE###'''
from prettytable import PrettyTable

table = PrettyTable()
table.field_names = ["Gene Symbol", "NCBI Gene ID"]

for gene_symbol, gene_id in gene_ids.items():
    table.add_row([gene_symbol, str(gene_id)])

print(table)
# Out:
# +------------------------------------------+--------------+
# |               Gene Symbol                | NCBI Gene ID |
# +------------------------------------------+--------------+
# |                   AKT3                   |     348      |
# |                  FRAT1                   |     7124     |
# |                  CASP12                  |     3569     |
# |              NDUFC2-KCTD14               |     351      |
# |                   PPIF                   |     3845     |
# |                  ADAM10                  |     673      |
# |                   CDK5                   |     207      |
# |                  PSMD14                  |     4790     |
# |              TPTEP2-CSNK1E               |     3553     |
# |                   APC2                   |     1499     |
# |                   RTN3                   |     6622     |
# |                  TUBA1B                  |     5743     |
# |                  TUBB3                   |     4137     |
# |                  TUBB4A                  |     2475     |
# |                  TUBB4B                  |     5594     |
# |                  ATP5PD                  |     5290     |
# | cytochrome c oxidase subunit NDUFA4-like |     5970     |
# |                  UQCR11                  |     2932     |
# |              P3R3URF-PIK3R3              |     355      |
# |                  ADRM1                   |     177      |
# |                  FZD10                   |     3630     |
# |                  TUBA3E                  |     836      |
# |                  CHRM1                   |     324      |
# |                  CHRM3                   |     5595     |
# |                  CHRM5                   |     5663     |
# |                  TUBA3D                  |     4843     |
# |                  CHRNA7                  |     3552     |
# |                   CHUK                   |     4023     |
# |                 CSNK1A1L                 |     841      |
# |             tubulin beta 8B              |     3643     |
# |                  COX6B2                  |     7132     |
# |                 NDUFA11                  |     1457     |
# |                  COX4I1                  |     8678     |
# |                  COX5B                   |     5295     |
# |                  COX6A1                  |     4893     |
# |                  COX6A2                  |    22943     |
# |                  COX6B1                  |     3667     |
# |                  COX6C                   |     5894     |
# |                  COX7A1                  |     7474     |
# |                  COX7A2                  |     6868     |
# |                  COX7B                   |     4035     |
# |                  COX7C                   |    23621     |
# |                  COX8A                   |     5624     |
# |                  PSMA8                   |     775      |
# |                   CSF1                   |     801      |
# |                 CSNK1A1                  |     2194     |
# |                  CSNK1E                  |     3551     |
# |                 CSNK2A1                  |     4311     |
# |                 CSNK2A2                  |     5610     |
# |                  CSNK2B                  |    50507     |
# |                   KLC3                   |     1536     |
# |                  CTNNB1                  |     4842     |
# |                   CYBB                   |     1139     |
# |                   CYC1                   |     8517     |
# |                  CALML6                  |     5604     |
# |                  DDIT3                   |     2597     |
# |                  COX7B2                  |     842      |
# |                   AGER                   |     102      |
# |                   DVL1                   |     1147     |
# |                   DVL2                   |     2904     |
# |                   DVL3                   |     1020     |
# |                  EIF2S1                  |     7494     |
# |                 SLC39A11                 |     7186     |
# |                   TUBB                   |     4041     |
# |                   AKT1                   |     2776     |
# |                   AKT2                   |     2081     |
# |                   ERN1                   |     468      |
# |                 SLC39A12                 |     488      |
# |                  ATG14                   |     208      |
# |                   ATF6                   |     1435     |
# |                   DKK1                   |     6390     |
# |                  ATG2A                   |     7416     |
# |                  PLCB1                   |     8772     |
# |                  NCSTN                   |     5742     |
# |                  FRAT2                   |     1649     |
# |                 SLC39A14                 |    10381     |
# |                  BACE1                   |     4217     |
# |                   MTOR                   |     2902     |
# |                   FZD2                   |     7471     |
# |                 SLC39A6                  |     1965     |
# |                  BACE2                   |     8408     |
# |                  GAPDH                   |     572      |
# |                  TUBB8B                  |     2903     |
# |                  WIPI2                   |     8660     |
# |                   NOX1                   |     4040     |
# |                  UQCRQ                   |     5664     |
# |                   DKK4                   |     9451     |
# |                   DKK2                   |    27035     |
# |                 SLC39A1                  |     8312     |
# |                   GNAQ                   |     1460     |
# |                 CSNK2A3                  |    89780     |
# |                 SLC39A5                  |     3708     |
# |                  GRIN1                   |     823      |
# |                  GRIN2A                  |     637      |
# |                  GRIN2B                  |    57142     |
# |                  GRIN2C                  |     4321     |
# |                  GRIN2D                  |    22926     |
# |                 SLC25A4                  |     5293     |
# |                   GRM5                   |     3416     |
# |                 SLC25A5                  |    10000     |
# |                 SLC25A6                  |     317      |
# |                  GSK3B                   |    203068    |
# |                  UQCR10                  |     1131     |
# |                  NRBF2                   |     5291     |
# |                 SLC39A3                  |     840      |
# |                 SLC39A2                  |     6392     |
# |                 HSD17B10                 |     5601     |
# |                  PIK3R4                  |     7846     |
# |                  APAF1                   |     1459     |
# |                  APBB1                   |     5710     |
# |                   APC                    |     6037     |
# |                   HRAS                   |   6775079    |
# |                   IDE                    |     8313     |
# |                  COX8C                   |     1452     |
# |                  TUBB8                   |     4535     |
# |                  TUBB2B                  |     5605     |
# |                   APOE                   |    54205     |
# |                   APP                    |     5289     |
# |                   FAS                    |    23385     |
# |                  IKBKB                   |     2915     |
# |                   IL1A                   |     824      |
# |                   IL1B                   |     498      |
# |                   IL6                    |     5705     |
# |                   INS                    |     506      |
# |                   INSR                   |     5530     |
# |                   IRS1                   |     4891     |
# |                   ARAF                   |     1454     |
# |                  ITPR1                   |     3799     |
# |                  ITPR2                   |     808      |
# |                  ITPR3                   |    10376     |
# |                  NDUFS7                  |     5296     |
# |                  KIF5A                   |     1128     |
# |                  KIF5B                   |     6389     |
# |                  KIF5C                   |     291      |
# |                   KLC1                   |     4508     |
# |                   KRAS                   |     3028     |
# |                   LPL                    |     779      |
# |                   LRP1                   |     805      |
# |                   LRP6                   |     5708     |
# |                   LRP5                   |     5687     |
# |                   MAPT                   |     1856     |
# |                  MAP3K5                  |    23236     |
# |                   MME                    |    10382     |
# |                  UQCRHL                  |     7277     |
# |                  BECN2                   |     292      |
# |                   ATP6                   |     8322     |
# |                   ATP8                   |     3710     |
# |                   COX1                   |     776      |
# |                   COX2                   |     7280     |
# |                   COX3                   |     5693     |
# |                   CYTB                   |     5688     |
# |                   ND1                    |    51079     |
# |                   ND2                    |     1855     |
# |                   ND3                    |    54361     |
# |                   ND4                    |     3798     |
# |                   ND4L                   |     5609     |
# |                   ND5                    |     7476     |
# |                   ND6                    |     5707     |
# |                   ATF4                   |     7417     |
# |                  NDUFA1                  |     5702     |
# |                  NDUFA2                  |     5701     |
# |                  NDUFA3                  |    10383     |
# |                  NDUFA4                  |     5704     |
# |                  NDUFA5                  |     322      |
# |                  NDUFA6                  |    55630     |
# |                  NDUFA7                  |     778      |
# |                  NDUFA8                  |     5684     |
# |                  NDUFA9                  |     9821     |
# |                 NDUFA10                  |    80326     |
# |                 NDUFAB1                  |    10213     |
# |                  NDUFB1                  |     4538     |
# |                  NDUFB2                  |     5715     |
# |                  NDUFB3                  |     5700     |
# |                  NDUFB4                  |     8324     |
# |                  NDUFB5                  |    11047     |
# |                  NDUFB6                  |     8851     |
# |                  NDUFB7                  |    90550     |
# |                  NDUFB8                  |     1857     |
# |                  NDUFB9                  |     4513     |
# |                 NDUFB10                  |     5682     |
# |                  NDUFC1                  |     5602     |
# |                  NDUFC2                  |     3936     |
# |                  NDUFS1                  |     5709     |
# |                  NDUFS2                  |     7472     |
# |                  NDUFS3                  |     8471     |
# |                  NDUFV1                  |     5706     |
# |                  NDUFS4                  |     293      |
# |                  NDUFS5                  |     4540     |
# |                  NDUFS6                  |     5685     |
# |                  NDUFS8                  |     4536     |
# |                  NDUFV2                  |     4512     |
# |                  NDUFV3                  |     6391     |
# |                  NFKB1                   |     5683     |
# |                   NOS1                   |    10313     |
# |                   NOS2                   |     5717     |
# |                  ATP2A1                  |    55851     |
# |                  ATP2A2                  |     5686     |
# |                  ATP2A3                  |     5689     |
# |                 SLC11A2                  |    64116     |
# |                   NRAS                   |    22863     |
# |                 ATP5F1A                  |    23516     |
# |                   NOX4                   |    55626     |
# |                 ATP5F1B                  |    25825     |
# |                 ATP5F1C                  |    84790     |
# |                 NDUFA13                  |     3831     |
# |                  APH1A                   |     8503     |
# |                 ATP5F1D                  |     369      |
# |                  WNT16                   |     5692     |
# |                 ATP5F1E                  |    89832     |
# |                  ATP5PB                  |     5718     |
# |                 ATP5MC1                  |     2906     |
# |                 ATP5MC2                  |     5713     |
# |                 ATP5MC3                  |     487      |
# |                  CALML5                  |     5534     |
# |                  TUBA8                   |     3709     |
# |                  ATP5PF                  |     2905     |
# |                  PIK3C3                  |     1327     |
# |                  PIK3CA                  |     9861     |
# |                  PIK3CB                  |     7480     |
# |                  PIK3CD                  |     5331     |
# |                  PIK3R1                  |     4719     |
# |                  PIK3R2                  |     7855     |
# |                  PLCB2                   |     7473     |
# |                  PLCB3                   |    84617     |
# |                  PLCB4                   |     4537     |
# |                  ATP5PO                  |     5330     |
# |                   CYCS                   |     4541     |
# |                   WNT4                   |    10105     |
# |                 NDUFB11                  |     4722     |
# |                   PPID                   |     7482     |
# |                  WIPI1                   |    347688    |
# |                  ATG2B                   |     5719     |
# |                  PPP3CA                  |     7385     |
# |                  PPP3CB                  |     5695     |
# |                  PPP3CC                  |     489      |
# |                 SLC39A9                  |     4724     |
# |                  PPP3R1                  |     6263     |
# |                  PPP3R2                  |     509      |
# |                  AMBRA1                  |     5691     |
# |                 SLC39A4                  |    25800     |
# |                  PSENEN                  |     5694     |
# |                  MAPK1                   |     7419     |
# |                  MAPK3                   |     7481     |
# |                 NDUFA12                  |     9776     |
# |                  MAPK8                   |    10010     |
# |                  MAPK9                   |     5532     |
# |                  MAPK10                  |     5690     |
# |                  MAP2K1                  |     8323     |
# |                  MAP2K2                  |     5714     |
# |                  MAP2K7                  |    347733    |
# |                 EIF2AK2                  |     4729     |
# |                  PSEN1                   |    81027     |
# |                  PSEN2                   |    29882     |
# |                  PSMA1                   |     5481     |
# |                  PSMA2                   |     7384     |
# |                  PSMA3                   |    51384     |
# |                  PSMA4                   |     7979     |
# |                  PSMA5                   |     4720     |
# |                  PSMA6                   |     539      |
# |                  PSMA7                   |    27123     |
# |                  PSMB1                   |    51107     |
# |                  PSMB2                   |     1537     |
# |                 NDUFA4L2                 |     7477     |
# |                  PSMB3                   |     8321     |
# |                  PSMB4                   |     7976     |
# |                  PSMB5                   |     4519     |
# |                  PSMB6                   |    81029     |
# |                  PSMB7                   |     4723     |
# |                  PSMC1                   |  100506742   |
# |                  PSMC2                   |    29986     |
# |                  PSMC3                   |     7922     |
# |                  PSMC4                   |     5533     |
# |                  PSMC5                   |     522      |
# |                  PSMC6                   |     7381     |
# |                  PSMD1                   |     4704     |
# |                  PSMD2                   |     2535     |
# |                  PSMD3                   |     8883     |
# |                  PSMD4                   |    30849     |
# |                  PSMD7                   |     4697     |
# |                  PSMD8                   |    51806     |
# |                   RTN4                   |    27173     |
# |                  PSMD9                   |     5332     |
# |                  PSMD11                  |     4698     |
# |                  PSMD12                  |     1329     |
# |                 SLC39A10                 |    55102     |
# |                  PSMD13                  |   6775094    |
# |                   BAD                    |     515      |
# |                  PTGS2                   |     810      |
# |                   RAF1                   |    27121     |
# |                   RELA                   |     4514     |
# |                  ATG101                  |    374291    |
# |                   RYR3                   |    10023     |
# |                   BID                    |     7278     |
# |                   SDHA                   |     8325     |
# |                   SDHB                   |    10297     |
# |                   SDHC                   |     4705     |
# |                   SDHD                   |    26100     |
# |                 SLC39A8                  |     9706     |
# |                   KLC2                   |     9377     |
# |                   SNCA                   |    64837     |
# |                   BRAF                   |    10476     |
# |                  ADAM17                  |     4728     |
# |                   TNF                    |    10625     |
# |                 TNFRSF1A                 |    51807     |
# |                  TRAF2                   |     7475     |
# |                  TUBA4A                  |     4702     |
# |                  TUBA3C                  |     7386     |
# |                  TUBB2A                  |     3800     |
# |                  UQCRB                   |     513      |
# |                  UQCRC1                  |    54539     |
# |                  UQCRC2                  |    11211     |
# |                 UQCRFS1                  |     7484     |
# |                  UQCRH                   |     1340     |
# |                  VDAC1                   |     4694     |
# |                  VDAC2                   |     4712     |
# |                  VDAC3                   |     1346     |
# |                   WNT1                   |     7483     |
# |                   WNT2                   |    84701     |
# |                   WNT3                   |     4706     |
# |                  WNT5A                   |     1133     |
# |                   WNT6                   |     1345     |
# |                  WNT7A                   |     7388     |
# |                  WNT7B                   |     1347     |
# |                  WNT8A                   |    57181     |
# |                  WNT8B                   |    55062     |
# |                  WNT10B                  |    55334     |
# |                  WNT11                   |    23130     |
# |                  WNT2B                   |    83464     |
# |                  WNT9A                   |     4509     |
# |                  WNT9B                   |    29982     |
# |                   XBP1                   |    22883     |
# |                 CACNA1C                  |     4715     |
# |                 CACNA1D                  |     4716     |
# |                 CACNA1F                  |     514      |
# |                 CACNA1S                  |     4725     |
# |                  TUBA1A                  |     4726     |
# |                   FZD5                   |    56901     |
# |                 SLC39A7                  |     4718     |
# |                   FZD3                   |   6775098    |
# |                   SEM1                   |     4731     |
# |                  TUBAL3                  |    55967     |
# |                  CALM1                   |     4695     |
# |                  WNT10A                  |     516      |
# |                  CALM2                   |  102800317   |
# |                  CALM3                   |    10438     |
# |                  CALML3                  |     8326     |
# |                  TUBB1                   |   6775063    |
# |                  WNT5B                   |    60673     |
# |                  CAPN1                   |     9167     |
# |                  CAPN2                   |     4714     |
# |                  AXIN1                   |    89953     |
# |                  AXIN2                   |     1337     |
# |                   FZD1                   |     4700     |
# |                   FZD4                   |     1349     |
# |                   FZD6                   |    283106    |
# |                   FZD7                   |   6775066    |
# |                   FZD8                   |     5535     |
# |                   FZD9                   |     4713     |
# |                 SLC25A31                 |    83447     |
# |                  APH1B                   |    91252     |
# |                  CASP3                   |   6775083    |
# |                  CASP7                   |    27089     |
# |                   ULK1                   |    29796     |
# |                  CASP8                   |    201266    |
# |                  CASP9                   |     4710     |
# |                  TUBB6                   |     4701     |
# |                  COX4I2                  |     1350     |
# |                   IRS4                   |    147700    |
# |                  TUBA1C                  |     1351     |
# |                  PIK3R3                  |     4711     |
# |                  IKBKG                   |     7479     |
# |                   IRS2                   |    143471    |
# |                  BECN1                   |    114787    |
# |                   FADD                   |    10983     |
# |                  CDK5R1                  |    112714    |
# |                   NAE1                   |    283375    |
# |                  WNT3A                   |     517      |
# |                 CHRFAM7A                 |    79085     |
# |                   KLC4                   |    113457    |
# |                   MCU                    |     1339     |
# |                 SLC39A13                 |   6775072    |
# |                 COX7A2L                  |     7478     |
# |                  CALML4                  |     4539     |
# |                  COX5A                   |    29985     |
# |                 EIF2AK3                  |    79861     |
# |                   ULK2                   |    23401     |
# |                  ATG13                   |     518      |
# |                  RB1CC1                  |     4709     |
# |                  PSMD6                   |    126328    |
# +------------------------------------------+--------------+

# %%
'''If you would like you can repeat the above process but for BioMart. You could also try retrieving other information fields, for example the gene name, description, chromosome, start and end position, etc. from BioMart. Use one of the two BioMart snippets in the GitHub to help you.'''
